# %% [markdown]
# # TE- OCEAN Reward System
#
# H1: The success rate (voted yes &  granted) of a whale address is higher than of a not whale address
#
# H2: Addresses are likely to always vote always the same, either yes or no over all rounds
#
# - Most voters are not critically evaluating projects value (always vote yes)
# - Some voters are just slashing projects (always vote no)
#
# H3: Mainly whales vote: voter engagement (out of the total token holders) is low, especially between small token holders

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('https://raw.githubusercontent.com/andrewpenland/OceanProtocol-Rounds-Data/main/ocean-votes-round-1-to-10.csv')
df.head()
# Out:
#    Unnamed: 0                                     address      balance Vote  \
# 0           0  0x9e95B6c35a43A61B06F19d21FBe008f17B1f5e44   300.011809  Yes
# 1           1  0x01e66950353400E93AEe7F041C0303103E2ef5Ab  5271.992999  Yes
# 2           2  0x362CfE20851584DF00a670b2c8460A3aafD35839  3268.114915  Yes
# 3           3  0x1Daf0b27e0F54a235abb5D52D276033394Eb8F49   567.687949  Yes
# 4           4  0xcC7E9b8331bea863a158589E8EBCF118C72d0683  7084.813123  Yes
#
#    Round        Project Name Proposal State     Grant Category Earmarks  \
# 0      1   Wisdom Of the Web    Not Granted  Build & Integrate  General
# 1      1  Operation Plankton    Not Granted           Outreach  General
# 2      1  Operation Plankton    Not Granted           Outreach  General
# 3      1       Ocean Academy         Funded           Outreach  General
# 4      1       Ocean Academy         Funded           Outreach  General
#
#    OCEAN Granted
# 0            0.0
# 1            0.0
# 2            0.0
# ...
